# %% [markdown]
# # Lesson 15｜Pandas 選取與篩選
#
# 從「我要看哪些資料？」開始學會查詢 DataFrame。
#
# 共 28 個逐步示範；請依序執行。
#
# > `lesson13_orders.csv` 已放在本課資料夾。單獨下載本 Notebook 時，請把 CSV 放在同一個資料夾。

# %% [markdown]
# ## 01｜讀取乾淨訂單資料
#
# 延續 Lesson 14：先讀取、預覽並確認形狀。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
print(df.head(3))
print(df.shape)
# Out:
#   order_id        date product category  quantity  unit_price city payment
# 0     A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 1     A002  2026-08-01      拿鐵       飲品         1         120   新北    行動支付
# 2     A003  2026-08-02      貝果       餐點         3          65   台中      現金
# (30, 8)

# %% [markdown]
# ## 02｜選一欄得到 Series
#
# 一組中括號選一欄，結果是一維 Series。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
products = df["product"]
print(type(products))
print(products.head())
# Out:
# <class 'pandas.core.series.Series'>
# 0    美式咖啡
# 1      拿鐵
# 2      貝果
# 3      紅茶
# 4      可頌
# Name: product, dtype: object

# %% [markdown]
# ## 03｜選多欄得到 DataFrame
#
# 雙中括號內放欄名 list，結果仍是二維表格。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
preview = df[["product", "quantity", "unit_price"]]
print(type(preview))
print(preview.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   product  quantity  unit_price
# 0    美式咖啡         2          80
# 1      拿鐵         1         120
# 2      貝果         3          65
# 3      紅茶         2          55
# 4      可頌         2          70

# %% [markdown]
# ## 04｜loc：用標籤或名稱找資料
#
# loc 是 label-based indexing。看到 loc，就先看 index 標籤與欄位名稱。

# %%
import pandas as pd

df_people = pd.DataFrame(
    {
        "name": ["JW", "Amy", "Bob"],
        "age": [30, 25, 28],
    },
    index=["a", "b", "c"],
)

print(df_people)
print("標籤 a 的整列：")
print(df_people.loc["a"])
print("標籤 a、name 欄：", df_people.loc["a", "name"])
# Out:
#   name  age
# a   JW   30
# b  Amy   25
# c  Bob   28
# 標籤 a 的整列：
# name    JW
# age     30
# Name: a, dtype: object
# 標籤 a、name 欄： JW

# %% [markdown]
# ## 05｜iloc：用整數位置找資料
#
# iloc 是 integer location。列與欄都從位置 0 開始計算。

# %%
import pandas as pd

df_people = pd.DataFrame(
    {
        "name": ["JW", "Amy", "Bob"],
        "age": [30, 25, 28],
    },
    index=["a", "b", "c"],
)

print(df_people)
print("第 0 列：")
print(df_people.iloc[0])
print("第 0 列、第 1 欄：", df_people.iloc[0, 1])
# Out:
#   name  age
# a   JW   30
# b  Amy   25
# c  Bob   28
# 第 0 列：
# name    JW
# age     30
# Name: a, dtype: object
# 第 0 列、第 1 欄： 30

# %% [markdown]
# ## 06｜loc 與 iloc 的切片終點
#
# loc 的標籤切片包含終點；iloc 和 Python slicing 一樣，不包含結尾位置。數字 index 也要先分清楚標籤與位置。

# %%
import pandas as pd

df_people = pd.DataFrame(
    {
        "name": ["JW", "Amy", "Bob"],
        "age": [30, 25, 28],
    },
    index=["a", "b", "c"],
)

loc_result = df_people.loc["a":"b"]
iloc_result = df_people.iloc[0:2]

print("loc 從 a 到 b，包含 b：")
print(loc_result)
print("iloc 從位置 0 到 2，不包含位置 2：")
print(iloc_result)

number_index_df = df_people.copy()
number_index_df.index = [10, 20, 30]

print("loc[10]：找標籤 10")
print(number_index_df.loc[10])
print("iloc[0]：找第 0 個位置")
print(number_index_df.iloc[0])
# Out:
# loc 從 a 到 b，包含 b：
#   name  age
# a   JW   30
# b  Amy   25
# iloc 從位置 0 到 2，不包含位置 2：
#   name  age
# a   JW   30
# b  Amy   25
# loc[10]：找標籤 10
# name    JW
# age     30
# Name: 10, dtype: object
# iloc[0]：找第 0 個位置
# name    JW
# age     30
# Name: 10, dtype: object

# %% [markdown]
# ## 07｜比較運算會產生布林條件
#
# 每一列都會得到 True 或 False。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["quantity"] >= 3
print(condition.head(10))
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: quantity, dtype: bool

# %% [markdown]
# ## 08｜先檢查條件再篩選
#
# 先看 True/False，確認條件寫對再套用。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["city"] == "台北"
print(condition.value_counts())
# Out:
# False    22
# True      8
# Name: city, dtype: int64

# %% [markdown]
# ## 09｜用條件留下符合的列
#
# 把布林條件放進 df[]，只有 True 的列會留下。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["quantity"] >= 3
result = df[condition]
print(result)

# %% [markdown]
# ## 10｜篩選高單價商品
#
# 數值欄可使用大於、小於、等於等比較運算。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df[df["unit_price"] >= 100]
print(result[["product", "unit_price"]])

# %% [markdown]
# ## 11｜篩選指定文字
#
# 字串欄也能用 == 找出完全相同的值。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df[df["payment"] == "信用卡"]
print(result.head())
# Out:
#    order_id        date product category  quantity  unit_price city payment
# 0      A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 4      A005  2026-08-03      可頌       餐點         2          70   台北     信用卡
# 6      A007  2026-08-04     三明治       餐點         1          95   台中     信用卡
# 9      A010  2026-08-05      貝果       餐點         2          65   新北     信用卡
# 12     A013  2026-08-07     三明治       餐點         2          95   台中     信用卡

# %% [markdown]
# ## 12｜排除指定值
#
# != 代表不等於。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df[df["city"] != "台北"]
print(result[["order_id", "city"]].head())
# Out:
#   order_id city
# 1     A002   新北
# 2     A003   台中
# 3     A004   高雄
# 5     A006   桃園
# 6     A007   台中

# %% [markdown]
# ## 13｜同時符合兩個條件：&
#
# 每個條件都要加括號，& 代表而且。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = (df["city"] == "台北") & (df["quantity"] >= 2)
#當你寫 print(df[condition])
#你是在告訴 Pandas：「請拿 df 這張表格，對照 condition 這張勾選單
#把標示為 True 的那幾列資料完整印出來。」
print(df[condition])
# Out:
#    order_id        date product category  quantity  unit_price city payment
# 0      A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 4      A005  2026-08-03      可頌       餐點         2          70   台北     信用卡
# 7      A008  2026-08-04    美式咖啡       飲品         4          80   台北      現金
# 19     A020  2026-08-10     三明治       餐點         2          95   台北    行動支付
# 23     A024  2026-08-12    抹茶拿鐵       飲品         2         130   台北     信用卡
# 27     A028  2026-08-14      拿鐵       飲品         2         120   台北    行動支付

# %% [markdown]
# ## 14｜符合其中一個條件：|
#
# | 代表或者，只要一邊是 True 就留下。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = (df["city"] == "台北") | (df["city"] == "高雄")
print(df[condition].head())
# Out:
#   order_id        date product category  quantity  unit_price city payment
# 0     A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 3     A004  2026-08-02      紅茶       飲品         2          55   高雄    行動支付
# 4     A005  2026-08-03      可頌       餐點         2          70   台北     信用卡
# 7     A008  2026-08-04    美式咖啡       飲品         4          80   台北      現金
# 8     A009  2026-08-05    抹茶拿鐵       飲品         1         130   高雄    行動支付

# %% [markdown]
# ## 15｜反轉條件：~
#
# ~ 會把 True 與 False 對調。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = ~(df["category"] == "飲品")
print(df[condition])

# %% [markdown]
# ## 16｜isin()：一次比對多個值
#
# 適合處理城市名單、商品名單等集合條件。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["city"].isin(["台北", "台中"] )
print(df[condition].head())
# Out:
#   order_id        date product category  quantity  unit_price city payment
# 0     A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 2     A003  2026-08-02      貝果       餐點         3          65   台中      現金
# 4     A005  2026-08-03      可頌       餐點         2          70   台北     信用卡
# 6     A007  2026-08-04     三明治       餐點         1          95   台中     信用卡
# 7     A008  2026-08-04    美式咖啡       飲品         4          80   台北      現金

# %% [markdown]
# ## 17｜between()：篩選數值區間
#
# 預設包含起點和終點。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["unit_price"].between(70, 100)
print(df[condition][["product", "unit_price"]])

# %% [markdown]
# ## 18｜str.contains()：文字包含
#
# 用 na=False 避免缺值造成條件錯誤。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["product"].str.contains("拿鐵", na=False)
print(df[condition])

# %% [markdown]
# ## 19｜loc：同時選列與欄
#
# 逗號左邊是列條件，右邊是想看的欄位。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["quantity"] >= 3
result = df.loc[condition, ["product", "quantity", "city"]]
print(result)
# Out:
#    product  quantity city
# 2       貝果         3   台中
# 7     美式咖啡         4   台北
# 10      紅茶         3   桃園
# 13      拿鐵         3   新北
# 17      可頌         3   台中
# 21    美式咖啡         3   桃園
# 25      紅茶         4   高雄
# 29      貝果         3   新北

# %% [markdown]
# ## 20｜sort_values()：由小到大
#
# ascending=True 是預設值。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df.sort_values("unit_price")
print(result[["product", "unit_price"]].head())

# %% [markdown]
# ## 21｜由大到小排序
#
# ascending=False 代表降冪排序。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df.sort_values("quantity", ascending=False)
print(result[["product", "quantity"]].head())

# %% [markdown]
# ## 22｜依多欄排序
#
# 先依第一欄排；相同時再看第二欄。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df.sort_values(["city", "quantity"], ascending=[True, False])
print(result[["city", "product", "quantity"]].head(10))

# %% [markdown]
# ## 23｜新增營業額欄位
#
# 欄位可以直接進行逐列運算。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["revenue"] = df["quantity"] * df["unit_price"]
print(df[["quantity", "unit_price", "revenue"]].head())

# %% [markdown]
# ## 24｜新增布林標記欄位
#
# 新欄位也可以保存 True/False。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["is_large_order"] = df["quantity"] >= 3
print(df[["order_id", "quantity", "is_large_order"]].head())

# %% [markdown]
# ## 25｜新增含稅價格欄位
#
# 計算後可使用 round() 控制小數位。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["price_with_tax"] = (df["unit_price"] * 1.05).round(1)
print(df[["unit_price", "price_with_tax"]].head())

# %% [markdown]
# ## 26｜串接選取、篩選與排序
#
# 每一步存成清楚變數，比一行寫完容易除錯。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["revenue"] = df["quantity"] * df["unit_price"]
selected = df[["order_id", "product", "city", "revenue"]]
filtered = selected[selected["revenue"] >= 200]
result = filtered.sort_values("revenue", ascending=False)
print(result)

# %% [markdown]
# ## 27｜排序後取前幾名
#
# 先 sort_values()，再 head() 取得 Top N。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["revenue"] = df["quantity"] * df["unit_price"]
top5 = df.sort_values("revenue", ascending=False).head(5)
print(top5[["order_id", "product", "revenue"]])

# %% [markdown]
# ## 28｜完整查詢流程
#
# 回答：台北或新北、營業額至少 150 元的訂單，依營業額排序。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["revenue"] = df["quantity"] * df["unit_price"]
city_condition = df["city"].isin(["台北", "新北"] )
revenue_condition = df["revenue"] >= 150
result = df.loc[city_condition & revenue_condition, ["order_id", "product", "city", "revenue"]]
result = result.sort_values("revenue", ascending=False)
print(result)
