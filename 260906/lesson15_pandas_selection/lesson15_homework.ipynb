# %% [markdown]
# # Lesson 15｜回家作業：找出值得關注的訂單
#
# > 請將本 Notebook 與 `lesson13_orders.csv` 放在同一個資料夾。

# %% [markdown]
# 使用 `lesson13_orders.csv`：
#
# 1. 先用 `loc` 或 `iloc` 抽查一列或一個儲存格。
# 2. 新增 revenue 欄位。
# 3. 篩選台北、新北或桃園且 revenue >= 150 的訂單。
# 4. 只保留 order_id、product、city、revenue。
# 5. 依 revenue 由大到小排序並顯示前 8 筆。
# 6. 用一句話說明查詢結果。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)

# 請從新增欄位開始完成
