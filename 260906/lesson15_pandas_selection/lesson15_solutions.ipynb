# %% [markdown]
# # Lesson 15｜Pandas 選取與篩選｜教師解答
#
# 共 28 題，題號與 Learning 對應。
#
# > `lesson13_orders.csv` 已放在本課資料夾，可直接搭配本 Notebook 執行。

# %% [markdown]
# ## 01｜讀取乾淨訂單資料
#
# 請依照說明完成：延續 Lesson 14：先讀取、預覽並確認形狀。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
print(df.head(3))
print(df.shape)

# %% [markdown]
# ## 02｜選一欄得到 Series
#
# 請依照說明完成：一組中括號選一欄，結果是一維 Series。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
products = df["product"]
print(type(products))
print(products.head())

# %% [markdown]
# ## 03｜選多欄得到 DataFrame
#
# 請依照說明完成：雙中括號內放欄名 list，結果仍是二維表格。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
preview = df[["product", "quantity", "unit_price"]]
print(type(preview))
print(preview.head())

# %% [markdown]
# ## 04｜loc：用標籤或名稱找資料
#
# 請依照說明完成：loc 是 label-based indexing。看到 loc，就先看 index 標籤與欄位名稱。

# %%
import pandas as pd

df_people = pd.DataFrame(
    {
        "name": ["JW", "Amy", "Bob"],
        "age": [30, 25, 28],
    },
    index=["a", "b", "c"],
)

print(df_people)
print("標籤 a 的整列：")
print(df_people.loc["a"])
print("標籤 a、name 欄：", df_people.loc["a", "name"])

# %% [markdown]
# ## 05｜iloc：用整數位置找資料
#
# 請依照說明完成：iloc 是 integer location。列與欄都從位置 0 開始計算。

# %%
import pandas as pd

df_people = pd.DataFrame(
    {
        "name": ["JW", "Amy", "Bob"],
        "age": [30, 25, 28],
    },
    index=["a", "b", "c"],
)

print(df_people)
print("第 0 列：")
print(df_people.iloc[0])
print("第 0 列、第 1 欄：", df_people.iloc[0, 1])

# %% [markdown]
# ## 06｜loc 與 iloc 的切片終點
#
# 請依照說明完成：loc 的標籤切片包含終點；iloc 和 Python slicing 一樣，不包含結尾位置。數字 index 也要先分清楚標籤與位置。

# %%
import pandas as pd

df_people = pd.DataFrame(
    {
        "name": ["JW", "Amy", "Bob"],
        "age": [30, 25, 28],
    },
    index=["a", "b", "c"],
)

loc_result = df_people.loc["a":"b"]
iloc_result = df_people.iloc[0:2]

print("loc 從 a 到 b，包含 b：")
print(loc_result)
print("iloc 從位置 0 到 2，不包含位置 2：")
print(iloc_result)

number_index_df = df_people.copy()
number_index_df.index = [10, 20, 30]

print("loc[10]：找標籤 10")
print(number_index_df.loc[10])
print("iloc[0]：找第 0 個位置")
print(number_index_df.iloc[0])

# %% [markdown]
# ## 07｜比較運算會產生布林條件
#
# 請依照說明完成：每一列都會得到 True 或 False。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["quantity"] >= 3
print(condition.head(10))

# %% [markdown]
# ## 08｜先檢查條件再篩選
#
# 請依照說明完成：先看 True/False，確認條件寫對再套用。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["city"] == "台北"
print(condition.value_counts())

# %% [markdown]
# ## 09｜用條件留下符合的列
#
# 請依照說明完成：把布林條件放進 df[]，只有 True 的列會留下。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["quantity"] >= 3
result = df[condition]
print(result)

# %% [markdown]
# ## 10｜篩選高單價商品
#
# 請依照說明完成：數值欄可使用大於、小於、等於等比較運算。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df[df["unit_price"] >= 100]
print(result[["product", "unit_price"]])

# %% [markdown]
# ## 11｜篩選指定文字
#
# 請依照說明完成：字串欄也能用 == 找出完全相同的值。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df[df["payment"] == "信用卡"]
print(result.head())

# %% [markdown]
# ## 12｜排除指定值
#
# 請依照說明完成：!= 代表不等於。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df[df["city"] != "台北"]
print(result[["order_id", "city"]].head())

# %% [markdown]
# ## 13｜同時符合兩個條件：&
#
# 請依照說明完成：每個條件都要加括號，& 代表而且。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = (df["city"] == "台北") & (df["quantity"] >= 2)
print(df[condition])

# %% [markdown]
# ## 14｜符合其中一個條件：|
#
# 請依照說明完成：| 代表或者，只要一邊是 True 就留下。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = (df["city"] == "台北") | (df["city"] == "高雄")
print(df[condition].head())

# %% [markdown]
# ## 15｜反轉條件：~
#
# 請依照說明完成：~ 會把 True 與 False 對調。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = ~(df["category"] == "飲品")
print(df[condition])

# %% [markdown]
# ## 16｜isin()：一次比對多個值
#
# 請依照說明完成：適合處理城市名單、商品名單等集合條件。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["city"].isin(["台北", "台中"] )
print(df[condition].head())

# %% [markdown]
# ## 17｜between()：篩選數值區間
#
# 請依照說明完成：預設包含起點和終點。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["unit_price"].between(70, 100)
print(df[condition][["product", "unit_price"]])

# %% [markdown]
# ## 18｜str.contains()：文字包含
#
# 請依照說明完成：用 na=False 避免缺值造成條件錯誤。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["product"].str.contains("拿鐵", na=False)
print(df[condition])

# %% [markdown]
# ## 19｜loc：同時選列與欄
#
# 請依照說明完成：逗號左邊是列條件，右邊是想看的欄位。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
condition = df["quantity"] >= 3
result = df.loc[condition, ["product", "quantity", "city"]]
print(result)

# %% [markdown]
# ## 20｜sort_values()：由小到大
#
# 請依照說明完成：ascending=True 是預設值。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df.sort_values("unit_price")
print(result[["product", "unit_price"]].head())

# %% [markdown]
# ## 21｜由大到小排序
#
# 請依照說明完成：ascending=False 代表降冪排序。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df.sort_values("quantity", ascending=False)
print(result[["product", "quantity"]].head())

# %% [markdown]
# ## 22｜依多欄排序
#
# 請依照說明完成：先依第一欄排；相同時再看第二欄。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
result = df.sort_values(["city", "quantity"], ascending=[True, False])
print(result[["city", "product", "quantity"]].head(10))

# %% [markdown]
# ## 23｜新增營業額欄位
#
# 請依照說明完成：欄位可以直接進行逐列運算。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["revenue"] = df["quantity"] * df["unit_price"]
print(df[["quantity", "unit_price", "revenue"]].head())

# %% [markdown]
# ## 24｜新增布林標記欄位
#
# 請依照說明完成：新欄位也可以保存 True/False。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["is_large_order"] = df["quantity"] >= 3
print(df[["order_id", "quantity", "is_large_order"]].head())

# %% [markdown]
# ## 25｜新增含稅價格欄位
#
# 請依照說明完成：計算後可使用 round() 控制小數位。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["price_with_tax"] = (df["unit_price"] * 1.05).round(1)
print(df[["unit_price", "price_with_tax"]].head())

# %% [markdown]
# ## 26｜串接選取、篩選與排序
#
# 請依照說明完成：每一步存成清楚變數，比一行寫完容易除錯。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["revenue"] = df["quantity"] * df["unit_price"]
selected = df[["order_id", "product", "city", "revenue"]]
filtered = selected[selected["revenue"] >= 200]
result = filtered.sort_values("revenue", ascending=False)
print(result)

# %% [markdown]
# ## 27｜排序後取前幾名
#
# 請依照說明完成：先 sort_values()，再 head() 取得 Top N。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["revenue"] = df["quantity"] * df["unit_price"]
top5 = df.sort_values("revenue", ascending=False).head(5)
print(top5[["order_id", "product", "revenue"]])

# %% [markdown]
# ## 28｜完整查詢流程
#
# 請依照說明完成：回答：台北或新北、營業額至少 150 元的訂單，依營業額排序。

# %%
from pathlib import Path
import pandas as pd

data_path = Path("lesson13_orders.csv")
df = pd.read_csv(data_path)
df["revenue"] = df["quantity"] * df["unit_price"]
city_condition = df["city"].isin(["台北", "新北"] )
revenue_condition = df["revenue"] >= 150
result = df.loc[city_condition & revenue_condition, ["order_id", "product", "city", "revenue"]]
result = result.sort_values("revenue", ascending=False)
print(result)
