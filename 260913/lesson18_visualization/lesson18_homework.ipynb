# %% [markdown]
# # Lesson 18｜回家作業：讓資料說人話
#
# 使用同資料夾的 `lesson18_sales.csv`，完成三張能回答問題的圖表。

# %% [markdown]
# ## 任務一｜類別比較
#
# 使用長條圖比較各城市總營業額，排序並標示標題與縱軸名稱。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 任務二｜時間趨勢
#
# 使用折線圖呈現每月營業額，確認月份依正確順序排列。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 任務三｜占比或關係
#
# 自行選擇圓餅圖或散佈圖，先寫下問題，再畫出能回答問題的圖。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 任務四｜圖表解讀
#
# 每張圖各寫一句「看到了什麼」，再寫一句「還不能直接證明什麼」。

# %% [markdown]
# ## 任務五｜輸出圖片
#
# 使用 `savefig()` 儲存至少一張圖，檔名要能看出內容。

# %%
# 請在這裡完成程式
