# %% [markdown]
# # Lesson 18｜Matplotlib 與圖表選擇｜課堂練習
#
# 共 25 題，題號與 Learning 對應。
#
# > 本課已附上 `lesson18_sales.csv`。請讓 CSV 與 Notebook 保持在同一個資料夾。

# %% [markdown]
# ## 01｜讀取並準備畫圖資料
#
# 請依照說明完成：日期先轉成 datetime，營業額先算好。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 02｜認識 pyplot
#
# 請依照說明完成：plt 是 Matplotlib 常見縮寫，負責建立與顯示圖表。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 03｜第一張長條圖
#
# 請依照說明完成：長條圖適合比較不同類別的大小。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 04｜排序後再畫長條圖
#
# 請依照說明完成：由大到小排列，觀眾更容易看出排名。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 05｜在長條上標示數值
#
# 請依照說明完成：少量類別可以直接顯示數字，方便精確比較。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 06｜橫向長條圖適合較長名稱
#
# 請依照說明完成：barh 能讓分類名稱保留更多水平空間。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 07｜折線圖呈現時間趨勢
#
# 請依照說明完成：時間放在橫軸，可以觀察上升、下降與轉折。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 08｜畫折線圖前先排序日期
#
# 請依照說明完成：若時間順序錯亂，折線會傳達錯誤故事。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 09｜用 marker 看清楚每個時間點
#
# 請依照說明完成：資料點不多時，marker 可以幫助對照每一期。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 10｜多條折線比較商品分類
#
# 請依照說明完成：同一張圖的線條不宜太多，否則很難追蹤。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 11｜圓餅圖顯示整體占比
#
# 請依照說明完成：分類少、加總為百分之百時，圓餅圖才容易閱讀。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 12｜圓餅圖不要塞太多分類
#
# 請依照說明完成：商品很多時改用排序長條圖，通常比較容易比較。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 13｜散佈圖觀察兩個數字的關係
#
# 請依照說明完成：每個點是一筆訂單，用來觀察單價與數量是否一起變化。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 14｜用顏色凸顯重點
#
# 請依照說明完成：其他類別使用中性色，重點類別使用醒目色。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 15｜顏色要有一致的意思
#
# 請依照說明完成：同一份報告中，同一分類盡量維持同一顏色。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 16｜figsize 控制畫布大小
#
# 請依照說明完成：投影片與 Notebook 可以使用不同大小，但比例要適合內容。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 17｜標題與軸標籤回答觀眾的疑問
#
# 請依照說明完成：標題說明圖表問題，軸標籤說明數字與分類。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 18｜淡淡的格線幫助估讀
#
# 請依照說明完成：格線應該輔助數字，不要搶走資料的注意力。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 19｜圖例只在需要辨認系列時出現
#
# 請依照說明完成：單一資料系列通常不需要圖例；多條線才需要。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 20｜長條圖通常從零開始
#
# 請依照說明完成：截斷縱軸會誇大類別之間的差異。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 21｜savefig 儲存完成的圖表
#
# 請依照說明完成：先儲存再 show，能把圖片放進報告或 GitHub。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 22｜Pandas plot 是 Matplotlib 的快速入口
#
# 請依照說明完成：先用 Pandas 建圖，再用 plt 補標題與標籤。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 23｜依問題選擇圖表
#
# 請依照說明完成：比較類別用長條圖；時間趨勢用折線圖；少量占比才考慮圓餅圖。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 24｜標記最高的長條
#
# 請依照說明完成：標註能把讀者注意力帶到最重要的數字。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 25｜完成兩張圖的分析摘要
#
# 請依照說明完成：左邊比較城市，右邊觀察月份趨勢。

# %%
# 請在這裡完成程式
