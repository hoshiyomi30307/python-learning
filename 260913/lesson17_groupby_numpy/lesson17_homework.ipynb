# %% [markdown]
# # Lesson 17｜回家作業：城市銷售報表
#
# 使用同資料夾的 `lesson17_sales.csv`，完成一份可以交給店長閱讀的摘要。

# %% [markdown]
# ## 任務一｜準備資料
#
# 讀取 CSV，建立 `revenue = quantity * unit_price`。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 任務二｜城市摘要
#
# 依城市計算總營業額、平均訂單金額、訂單數與不重複顧客數，並依總營業額由高到低排序。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 任務三｜分類摘要
#
# 同時依城市與商品分類分組，找出各城市營業額最高的分類。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 任務四｜NumPy 數值挑戰
#
# 把 `revenue` 欄位轉成 NumPy 陣列，計算總和、平均，並留下高於平均值的訂單金額。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 任務五｜寫出結論
#
# 用 2～3 句話回答：哪個城市營業額最高？哪個分類值得優先關注？請引用實際數字。
