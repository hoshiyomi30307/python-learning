# %% [markdown]
# # Lesson 17｜資料整理、統計與 NumPy 橋接｜課堂練習
#
# 共 25 題，題號與 Learning 對應。
#
# > 本課已附上 `lesson17_sales.csv`。請讓 CSV 與 Notebook 保持在同一個資料夾。

# %% [markdown]
# ## 01｜讀取銷售資料
#
# 請依照說明完成：先確認資料筆數與欄位，再開始分組。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 02｜建立營業額欄位
#
# 請依照說明完成：每筆營業額等於數量乘上單價。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 03｜依城市加總營業額
#
# 請依照說明完成：groupby 先把相同城市放在一起，sum 再計算每組總和。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 04｜看懂 groupby 的分組
#
# 請依照說明完成：groups 可以查看 Pandas 建立了哪些群組。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 05｜分組結果預設是 Series
#
# 請依照說明完成：分類名稱通常會成為索引。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 06｜用 as_index=False 保留 DataFrame
#
# 請依照說明完成：結果仍是表格時，後續篩選與畫圖通常比較直覺。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 07｜把營業額由高到低排列
#
# 請依照說明完成：先彙總再排序，就能看到表現最好的城市。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 08｜計算各城市平均訂單金額
#
# 請依照說明完成：mean 回答的是每筆訂單平均多少錢。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 09｜count 計算非空白值
#
# 請依照說明完成：選定欄位後，count 只計算該欄不是空值的數量。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 10｜size 計算每組資料列數
#
# 請依照說明完成：size 直接計算每個群組有幾列。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 11｜nunique 計算不重複顧客
#
# 請依照說明完成：訂單數與顧客數回答不同問題。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 12｜agg 一次做多種統計
#
# 請依照說明完成：同一個營業額欄位可以同時計算總和、平均與最大值。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 13｜使用清楚的統計欄名
#
# 請依照說明完成：命名彙總能讓報表直接表達每一欄的意思。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 14｜同時依城市與分類分組
#
# 請依照說明完成：問題變成每個城市的每個商品分類表現如何。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 15｜reset_index 把索引變回欄位
#
# 請依照說明完成：多層分組後轉回一般表格，比較容易繼續處理。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 16｜篩選彙總後的結果
#
# 請依照說明完成：先完成分組，再留下總營業額達到門檻的城市。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 17｜先確認統計問題再選欄位
#
# 請依照說明完成：單價總和通常沒有商業意義，銷售分析更常加總營業額。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 18｜NumPy 把一串數字變成陣列
#
# 請依照說明完成：ndarray 適合進行大量數值運算，也是 Pandas 的重要基礎。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 19｜查看 ndarray 的形狀與型態
#
# 請依照說明完成：shape 說明陣列結構，dtype 說明元素的資料型態。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 20｜向量化運算一次處理全部數字
#
# 請依照說明完成：陣列乘上 1.05，會把每個價格都計算一次。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 21｜布林遮罩篩選 NumPy 陣列
#
# 請依照說明完成：條件會先產生 True 與 False，再留下符合的數字。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 22｜NumPy 的加總與平均
#
# 請依照說明完成：陣列可以直接呼叫 sum 與 mean。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 23｜List 與 ndarray 的乘法不同
#
# 請依照說明完成：List 乘以 2 會重複內容；NumPy 陣列乘以 2 會計算每個元素。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 24｜Pandas 欄位可以轉成 NumPy 陣列
#
# 請依照說明完成：to_numpy 讓 Series 的數字交給 NumPy 處理。

# %%
# 請在這裡完成程式

# %% [markdown]
# ## 25｜完成城市銷售摘要
#
# 請依照說明完成：把新增欄位、分組、統計與排序串成完整流程。

# %%
# 請在這裡完成程式
