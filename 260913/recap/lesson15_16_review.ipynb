# %% [markdown]
# # Lesson 15–16 課前複習
#
# 用簡單訂單資料複習 Pandas 選取、篩選、排序、新增欄位與資料清理。
#
# - Lesson 15：題目 1–8，練習選欄、`loc`、`iloc`、條件篩選與排序。
# - Lesson 16：題目 9–15，練習缺值、重複、文字、數字與日期清理。
# - 整合：題目 16，建立一份可以繼續分析的乾淨訂單表。
#
# 請把以下兩個 CSV 和 Notebook 放在同一資料夾：
#
# - `lesson15_16_review_orders.csv`
# - `lesson15_16_review_dirty_orders.csv`
#
# 題目不需要一次全部完成。先做會的部分，再依提示逐步補齊。

# %% [markdown]
# ## Lesson 15｜題目 1：讀取資料並快速確認
#
# 讀取 `lesson15_16_review_orders.csv`，印出前 3 列與表格大小。

# %%
from pathlib import Path
import pandas as pd

csv_path = Path("lesson15_16_review_orders.csv")
df = pd.read_csv(csv_path)

# 請印出前 3 列與表格大小

# %% [markdown]
# ## Lesson 15｜題目 2：選一欄與選多欄
#
# 分別選出 `product` 單一欄，以及 `product`、`quantity`、`unit_price` 三欄。觀察 Series 與 DataFrame 的差異。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_orders.csv"))

# 請建立 products 與 order_detail
# products =
# order_detail =

# 請印出兩個結果的型態與前 3 列

# %% [markdown]
# ## Lesson 15｜題目 3：loc 看標籤，iloc 看位置
#
# 用 `loc` 取得 index 標籤為 0 的商品名稱，再用 `iloc` 取得第 0 列、第 2 欄的商品名稱。兩個結果應相同。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_orders.csv"))

# 請分別使用 loc 與 iloc 取得第一筆商品名稱

# %% [markdown]
# ## Lesson 15｜題目 4：loc 與 iloc 的切片終點
#
# 比較 `df.loc[0:2]` 與 `df.iloc[0:2]` 的資料列數。說明哪一個包含終點。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_orders.csv"))

# 請建立 loc_result 與 iloc_result
# 請印出兩個結果與資料列數

# %% [markdown]
# ## Lesson 15｜題目 5：簡單條件篩選
#
# 找出數量 `quantity >= 2` 的訂單，只顯示訂單編號、商品與數量。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_orders.csv"))

# 請建立條件並篩選資料

# %% [markdown]
# ## Lesson 15｜題目 6：同時符合兩個條件
#
# 找出城市是台北，而且分類是飲品的訂單。提醒：Pandas 的『而且』使用 `&`，每個條件都要加括號。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_orders.csv"))

# 請建立 city_condition、category_condition 與 combined_condition
# 請印出篩選結果

# %% [markdown]
# ## Lesson 15｜題目 7：快速比對多個值與區間
#
# 完成三個小查詢：① 城市是台北或台中的訂單；② 單價介於 70～120 元；③ 商品名稱包含『拿鐵』。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_orders.csv"))

# ① 請使用 isin()
# ② 請使用 between()
# ③ 請使用 str.contains()

# 請分別印出三個查詢結果

# %% [markdown]
# ## Lesson 15｜題目 8：新增營業額並找出前三名
#
# 新增 `revenue = quantity * unit_price`，依營業額由大到小排序，再印出前 3 筆訂單。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_orders.csv"))

# 請新增 revenue
# 請排序並取前 3 筆
# 請印出 order_id、product、revenue

# %% [markdown]
# ## Lesson 16｜題目 9：保留原始資料
#
# 讀取 `lesson15_16_review_dirty_orders.csv`，立刻用 `copy()` 保留原始 DataFrame，再印出欄名與前 5 列。

# %%
from pathlib import Path
import pandas as pd

csv_path = Path("lesson15_16_review_dirty_orders.csv")
df = pd.read_csv(csv_path)

# 請建立 raw_df
# 請印出欄名與前 5 列

# %% [markdown]
# ## Lesson 16｜題目 10：整理欄位名稱
#
# 把欄名前後空白移除、改成小寫，並把欄名中的空格改成底線。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_dirty_orders.csv"))

# 請整理 df.columns
# 整理後應包含 order_id、order_date、unit_price
# 請印出新欄名

# %% [markdown]
# ## Lesson 16｜題目 11：檢查缺失值
#
# 先整理欄名，再用 `isna().sum()` 計算每一欄的缺失值，並找出至少有一個缺值的資料列。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_dirty_orders.csv"))
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_", regex=False)

# 請建立 missing_count
# 請找出含缺值的資料列

# %% [markdown]
# ## Lesson 16｜題目 12：補值與刪除重要缺值
#
# 把空白的城市與付款方式補成『未知』；數量或單價缺失時先刪除該列。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_dirty_orders.csv"))
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_", regex=False)

# 請用 fillna() 處理 city 與 payment
# 請用 dropna() 移除 quantity 或 unit_price 缺失的列
# 請印出處理後缺失值數量

# %% [markdown]
# ## Lesson 16｜題目 13：找出並移除重複訂單
#
# 以 `order_id` 判斷重複，先印出所有重複資料，再保留第一筆並移除其餘重複資料。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_dirty_orders.csv"))
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_", regex=False)

# 請找出重複 order_id
# 請建立移除重複後的 deduplicated_df

# %% [markdown]
# ## Lesson 16｜題目 14：整理文字內容
#
# 清除商品與城市前後空白，把『台北市、台中市、高雄市』統一成不含『市』的名稱，再把付款方式統一成中文。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_dirty_orders.csv"))
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_", regex=False)

# 請整理 product 與 city 前後空白
# 請統一 city
# 請先把 payment 轉小寫，再統一成信用卡、行動支付、現金

# %% [markdown]
# ## Lesson 16｜題目 15：安全轉換數字與日期
#
# 使用 `to_numeric(errors='coerce')` 轉換數量與單價，再使用 `to_datetime(errors='coerce')` 轉換日期。印出無法轉換的原始值。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_dirty_orders.csv"))
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_", regex=False)

# 先保留 quantity 與 order_date 的原始內容
# 日期請先把 / 統一成 -
# 請安全轉換 quantity、unit_price 與 order_date
# 請找出轉換後變成缺值、但原始內容不是空白的資料

# %% [markdown]
# ## Lesson 15–16｜題目 16：整合練習：建立可分析訂單表
#
# 從髒資料建立 `clean_df`：整理欄名、文字、缺值、重複、數字與日期，最後新增營業額並印出清理摘要。按照註解一步一步完成即可。

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv(Path("lesson15_16_review_dirty_orders.csv"))
raw_df = df.copy()

# 1. 整理欄名
# 2. 整理 product、city、payment 文字
# 3. 補上 city 與 payment 的缺值
# 4. 安全轉換 quantity、unit_price、order_date（日期先統一分隔符號）
# 5. 依 order_id 移除重複
# 6. 移除重要欄位仍有缺值的列
# 7. 新增 revenue
# 8. 印出原始筆數、清理後筆數、缺值與前 5 列
