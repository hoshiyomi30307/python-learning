# %% [markdown]
# # Lesson 14｜Pandas 與 DataFrame
#
# 讀入 CSV 後，先看懂資料，再開始分析。
#
# 共 25 個逐步示範；請依序執行。

# %% [markdown]
# ## 01｜匯入 Pandas
#
# 慣例把 pandas 簡寫成 pd，之後的教材與官方文件都常看到這個寫法。

# %%
import pandas as pd
print("Pandas 版本：", pd.__version__)
# Out:
# Pandas 版本： 1.5.3

# %% [markdown]
# ## 02｜準備資料路徑
#
# 同一份 Notebook 從專案根目錄或課程資料夾開啟都能找到資料。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv

# %% [markdown]
# ## 03｜read_csv：把 CSV 載入 DataFrame
#
# `pd.read_csv()` 會讀取標題列、資料列，並嘗試判斷欄位型態。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
#    order_id        date product category  quantity  unit_price city payment
# 0      A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 1      A002  2026-08-01      拿鐵       飲品         1         120   新北    行動支付
# 2      A003  2026-08-02      貝果       餐點         3          65   台中      現金
# 3      A004  2026-08-02      紅茶       飲品         2          55   高雄    行動支付
# 4      A005  2026-08-03      可頌       餐點         2          70   台北     信用卡
# 5      A006  2026-08-03      拿鐵       飲品         2         120   桃園    行動支付
# 6      A007  2026-08-04     三明治       餐點         1          95   台中     信用卡
# 7      A008  2026-08-04    美式咖啡       飲品         4          80   台北      現金
# 8      A009  2026-08-05    抹茶拿鐵       飲品         1         130   高雄    行動支付
# 9      A010  2026-08-05      貝果       餐點         2          65   新北     信用卡
# 10     A011  2026-08-06      紅茶       飲品         3          55   桃園      現金
# 11     A012  2026-08-06      可頌       餐點         1          70   台北    行動支付
# 12     A013  2026-08-07     三明治       餐點         2          95   台中     信用卡
# 13     A014  2026-08-07      拿鐵       飲品         3         120   新北    行動支付
# 14     A015  2026-08-08    美式咖啡       飲品         2          80   高雄      現金
# 15     A016  2026-08-08      貝果       餐點         1          65   台北     信用卡
# 16     A017  2026-08-09    抹茶拿鐵       飲品         2         130   桃園    行動支付
# 17     A018  2026-08-09      可頌       餐點         3          70   台中      現金
# 18     A019  2026-08-10      紅茶       飲品         1          55   新北     信用卡
# 19     A020  2026-08-10     三明治       餐點         2          95   台北    行動支付
# 20     A021  2026-08-11      拿鐵       飲品         1         120   高雄     信用卡
# 21     A022  2026-08-11    美式咖啡       飲品         3          80   桃園      現金
# 22     A023  2026-08-12      貝果       餐點         2          65   台中    行動支付
# 23     A024  2026-08-12    抹茶拿鐵       飲品         2         130   台北     信用卡
# 24     A025  2026-08-13      可頌       餐點         1          70   新北      現金
# 25     A026  2026-08-13      紅茶       飲品         4          55   高雄    行動支付
# 26     A027  2026-08-14     三明治       餐點         1          95   桃園     信用卡
# 27     A028  2026-08-14      拿鐵       飲品         2         120   台北    行動支付
# 28     A029  2026-08-15    美式咖啡       飲品         1          80   台中      現金
# 29     A030  2026-08-15      貝果       餐點         3          65   新北     信用卡

# %% [markdown]
# ## 04｜確認物件是 DataFrame
#
# DataFrame 是 Pandas 用來表示二維表格的主要物件。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(type(df))
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## 05｜head()：先看前 5 列
#
# 剛讀完資料先抽看內容，確認分隔與欄位沒有讀歪。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.head())#預設是5列
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
#   order_id        date product category  quantity  unit_price city payment
# 0     A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 1     A002  2026-08-01      拿鐵       飲品         1         120   新北    行動支付
# 2     A003  2026-08-02      貝果       餐點         3          65   台中      現金
# 3     A004  2026-08-02      紅茶       飲品         2          55   高雄    行動支付
# 4     A005  2026-08-03      可頌       餐點         2          70   台北     信用卡

# %% [markdown]
# ## 06｜head(n)：自行決定要看幾列
#
# 括號裡的數字是要顯示的列數。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.head(3))
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
#   order_id        date product category  quantity  unit_price city payment
# 0     A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 1     A002  2026-08-01      拿鐵       飲品         1         120   新北    行動支付
# 2     A003  2026-08-02      貝果       餐點         3          65   台中      現金

# %% [markdown]
# ## 07｜tail()：查看最後幾列
#
# 檔案尾端也可能有異常資料，因此不能永遠只看開頭。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.tail(3))#查看尾端
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
#    order_id        date product category  quantity  unit_price city payment
# 27     A028  2026-08-14      拿鐵       飲品         2         120   台北    行動支付
# 28     A029  2026-08-15    美式咖啡       飲品         1          80   台中      現金
# 29     A030  2026-08-15      貝果       餐點         3          65   新北     信用卡

# %% [markdown]
# ## 08｜shape：幾列 × 幾欄
#
# shape 是屬性，不用加括號；結果是一個 `(列數, 欄數)` tuple。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)

print("資料形狀：", df.shape)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# 資料形狀： (30, 8)

# %% [markdown]
# ## 09｜把列數與欄數分開命名
#
# 拆開 tuple 後，輸出會比只看到 `(30, 8)` 更容易理解。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
row_count, column_count = df.shape
print("列數：", row_count)
print("欄數：", column_count)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# 列數： 30
# 欄數： 8

# %% [markdown]
# ## 10｜columns：有哪些欄位
#
# 先確認真正的欄名，避免後面因大小寫或拼字不同而出錯。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.columns)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# Index(['order_id', 'date', 'product', 'category', 'quantity', 'unit_price',
#        'city', 'payment'],
#       dtype='object')

# %% [markdown]
# ## 11｜把欄名轉成一般 list
#
# Index 可用於 Pandas；轉為 list 後對新手更熟悉，也方便逐一處理。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
column_names = list(df.columns)
print(column_names)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# ['order_id', 'date', 'product', 'category', 'quantity', 'unit_price', 'city', 'payment']

# %% [markdown]
# ## 12｜dtypes：每一欄的資料型態
#
# 文字常顯示為 object；整數通常是 int64。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.dtypes)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# order_id      object
# date          object
# product       object
# category      object
# quantity       int64
# unit_price     int64
# city          object
# payment       object
# dtype: object

# %% [markdown]
# ## 13｜檢查指定欄位的型態
#
# 用欄名從 dtypes 取得單一欄位型態。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print("quantity 型態：", df.dtypes["quantity"])
print("product 型態：", df.dtypes["product"])
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# quantity 型態： int64
# product 型態： object

# %% [markdown]
# ## 14｜index：每列的索引標籤
#
# 目前索引從 0 開始；索引是 DataFrame 用來定位列的標籤。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.index)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# RangeIndex(start=0, stop=30, step=1)

# %% [markdown]
# ## 15｜選一欄會得到 Series
#
# Series 像 DataFrame 裡的一根欄；它是一維資料。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
products = df["product"]
print(type(products))
print(products.head())
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# <class 'pandas.core.series.Series'>
# 0    美式咖啡
# 1      拿鐵
# 2      貝果
# 3      紅茶
# 4      可頌
# Name: product, dtype: object

# %% [markdown]
# ## 16｜選多欄仍然是 DataFrame
#
# 雙中括號中的 list 決定要保留哪些欄。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
preview = df[["product", "quantity"]]
print(type(preview))
print(preview.head())
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# <class 'pandas.core.frame.DataFrame'>
#   product  quantity
# 0    美式咖啡         2
# 1      拿鐵         1
# 2      貝果         3
# 3      紅茶         2
# 4      可頌         2

# %% [markdown]
# ## 17｜Series 與 DataFrame 的 shape 不同
#
# Series 只有長度；DataFrame 同時有列數與欄數。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
series = df["product"]
table = df[["product"]]
print("Series shape：", series.shape)
print("DataFrame shape：", table.shape)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# Series shape： (30,)
# DataFrame shape： (30, 1)

# %% [markdown]
# ## 18｜info()：一次看結構摘要
#
# 可以同時看到列數、欄位、非空值數量與型態。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
df.info()

# %% [markdown]
# ## 19｜sample()：隨機抽看資料
#
# 只看前幾列可能漏掉問題；固定 random_state 可讓每次抽樣一致。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.sample(3, random_state=7))

# %% [markdown]
# ## 20｜describe()：數值欄位摘要
#
# 快速查看筆數、平均、最小與最大值；此處先學會閱讀，不急著背公式。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.describe())

# %% [markdown]
# ## 21｜isna().sum()：每欄缺幾格
#
# 先得到 True/False，再用 sum() 計算每欄缺值數量。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.isna().sum())

# %% [markdown]
# ## 22｜duplicated().sum()：有幾列完全重複
#
# 完整重複列可能是重複匯入，但是否刪除仍要看業務情境。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print("完整重複列：", df.duplicated().sum())

# %% [markdown]
# ## 23｜檢查關鍵編號是否重複
#
# 即使整列不完全相同，order_id 重複仍值得確認。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print("重複訂單編號：", df["order_id"].duplicated().sum())

# %% [markdown]
# ## 24｜nunique()：每欄有幾種值
#
# 可以快速知道商品、城市、付款方式各有多少種類。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df[["product", "city", "payment"]].nunique())

# %% [markdown]
# ## 25｜建立可重複使用的健康檢查函式
#
# 把固定巡檢步驟包成函式，以後每次讀新資料都能使用。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd

def inspect_dataframe(dataframe):
    print("前 3 列：")
    print(dataframe.head(3))
    print("\n資料形狀：", dataframe.shape)
    print("欄位：", list(dataframe.columns))
    print("\n資料型態：")
    print(dataframe.dtypes)
    print("\n每欄缺值：")
    print(dataframe.isna().sum())
    print("完整重複列：", dataframe.duplicated().sum())

df = pd.read_csv(data_path)
inspect_dataframe(df)
