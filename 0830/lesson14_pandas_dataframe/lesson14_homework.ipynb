# %% [markdown]
# # Lesson 14｜回家作業：DataFrame 健康檢查報告

# %% [markdown]
# 請使用 Pandas 讀取 `course_v2/data/lesson13_orders.csv`，完成一份分析前巡檢報告。
#
# ## 任務
#
# 1. 顯示前 5 列、後 3 列與隨機 4 列。
# 2. 清楚印出列數、欄數與所有欄名。
# 3. 印出各欄資料型態與數值欄位摘要。
# 4. 檢查每欄缺值、完整重複列、重複訂單編號。
# 5. 比較 `df['city']` 與 `df[['city']]` 的型態與 shape。
# 6. 用自己的話寫下：這份資料是否已經可以進入下一步分析？為什麼？
#
# 請勿在這份作業中進行篩選、排序或 groupby；那些會在後續課程正式學習。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd

df = pd.read_csv(data_path)

# 1. 抽看資料

# 2. 檢查形狀與欄名

# 3. 檢查型態與數值摘要

# 4. 檢查缺值與重複

# 5. 比較 Series 與 DataFrame

# 6. 寫下你的判斷
