# %% [markdown]
# # Lesson 14｜Pandas 與 DataFrame｜課堂練習
#
# 共 25 題，題號與 Learning 對應。

# %% [markdown]
# ## 01｜匯入 Pandas
#
# 用慣例名稱 pd 匯入 pandas，印出版本。

# %%
# 請完成
import pandas as pd
print("Pandas 版本：", pd.__version__)
# Out:
# Pandas 版本： 1.5.3

# %% [markdown]
# ## 02｜建立資料路徑
#
# 執行路徑程式，確認資料檔存在。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv

# %% [markdown]
# ## 03｜讀取 CSV
#
# 使用 pd.read_csv() 把資料存入 df。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.head())
# 請完成
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
#   order_id        date product category  quantity  unit_price city payment
# 0     A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 1     A002  2026-08-01      拿鐵       飲品         1         120   新北    行動支付
# 2     A003  2026-08-02      貝果       餐點         3          65   台中      現金
# 3     A004  2026-08-02      紅茶       飲品         2          55   高雄    行動支付
# 4     A005  2026-08-03      可頌       餐點         2          70   台北     信用卡

# %% [markdown]
# ## 04｜確認 DataFrame 型態
#
# 印出 df 的 type。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(type(df))
# 請完成
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## 05｜查看前 5 列
#
# 使用 head()。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.head())
# 請完成
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
#   order_id        date product category  quantity  unit_price city payment
# 0     A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 1     A002  2026-08-01      拿鐵       飲品         1         120   新北    行動支付
# 2     A003  2026-08-02      貝果       餐點         3          65   台中      現金
# 3     A004  2026-08-02      紅茶       飲品         2          55   高雄    行動支付
# 4     A005  2026-08-03      可頌       餐點         2          70   台北     信用卡

# %% [markdown]
# ## 06｜查看前 8 列
#
# 在 head() 中傳入正確數字。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.head(8))
# 請完成
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
#   order_id        date product category  quantity  unit_price city payment
# 0     A001  2026-08-01    美式咖啡       飲品         2          80   台北     信用卡
# 1     A002  2026-08-01      拿鐵       飲品         1         120   新北    行動支付
# 2     A003  2026-08-02      貝果       餐點         3          65   台中      現金
# 3     A004  2026-08-02      紅茶       飲品         2          55   高雄    行動支付
# 4     A005  2026-08-03      可頌       餐點         2          70   台北     信用卡
# 5     A006  2026-08-03      拿鐵       飲品         2         120   桃園    行動支付
# 6     A007  2026-08-04     三明治       餐點         1          95   台中     信用卡
# 7     A008  2026-08-04    美式咖啡       飲品         4          80   台北      現金

# %% [markdown]
# ## 07｜查看最後 4 列
#
# 使用 tail()。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print(df.tail(4))
# 請完成
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
#    order_id        date product category  quantity  unit_price city payment
# 26     A027  2026-08-14     三明治       餐點         1          95   桃園     信用卡
# 27     A028  2026-08-14      拿鐵       飲品         2         120   台北    行動支付
# 28     A029  2026-08-15    美式咖啡       飲品         1          80   台中      現金
# 29     A030  2026-08-15      貝果       餐點         3          65   新北     信用卡

# %% [markdown]
# ## 08｜取得資料形狀
#
# 印出 df.shape，注意 shape 不加括號。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
print("資料形狀:",df.shape)
# 請完成
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# 資料形狀: (30, 8)

# %% [markdown]
# ## 09｜分別印出列數與欄數
#
# 把 df.shape 拆成 row_count、column_count。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
    Path("C:/Users/USER/Desktop/data/lesson13_orders.csv")
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
row_count, row_column = df.shape
print("列數:",row_count)
print("行數:",row_column)


# 請完成
# Out:
# 資料位置： C:\Users\USER\Desktop\data\lesson13_orders.csv
# 列數: 30
# 行數: 8

# %% [markdown]
# ## 10｜取得欄名
#
# 印出 df.columns。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 11｜欄名轉成 list
#
# 將 df.columns 轉為一般 list。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 12｜查看所有欄位型態
#
# 印出 df.dtypes。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 13｜指定欄位型態
#
# 印出 unit_price 的 dtype。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 14｜查看索引
#
# 印出 df.index。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 15｜選取一欄
#
# 把 city 欄存成 cities，印出型態與前 5 筆。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 16｜選取多欄
#
# 選 product、quantity、unit_price 三欄，存成 preview。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 17｜比較 Series 與 DataFrame
#
# 分別建立 df['product'] 與 df[['product']]，印出兩者型態。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 18｜執行 info()
#
# 呼叫 df.info()，觀察非空值與型態。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 19｜隨機抽看 5 列
#
# 使用 sample() 並設定 random_state=10。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 20｜查看數值摘要
#
# 呼叫 describe()。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 21｜統計每欄缺值
#
# 串接 isna() 與 sum()。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 22｜計算完整重複列
#
# 串接 duplicated() 與 sum()。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 23｜檢查 order_id 重複
#
# 只針對 order_id 欄執行 duplicated().sum()。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 24｜計算三欄唯一值數量
#
# 選 product、city、payment 後呼叫 nunique()。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd
df = pd.read_csv(data_path)
# 請完成

# %% [markdown]
# ## 25｜完成健康檢查函式
#
# 建立 inspect_dataframe()，印出 head(3)、shape、columns、dtypes、缺值與重複列。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import pandas as pd

def inspect_dataframe(dataframe):
    # 請完成
    pass

df = pd.read_csv(data_path)
inspect_dataframe(df)
