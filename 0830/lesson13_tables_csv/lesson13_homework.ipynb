# %% [markdown]
# # Lesson 13｜回家作業：訂單資料偵探

# %% [markdown]
# 請使用 `course_v2/data/lesson13_orders.csv` 完成一份小型調查報告。
#
# ## 任務
#
# 1. 使用 `csv.DictReader` 讀取資料，印出欄名、資料筆數與前 3 筆訂單。
# 2. 算出總銷售件數與總營業額。
# 3. 列出所有不重複城市與付款方式。
# 4. 檢查空白儲存格與重複訂單編號。
# 5. 最後用文字寫出一個你還想追查的分析問題，以及回答它需要哪些欄位。
#
# 請保留每一步輸出，讓老師看得見你的思考過程。

# %%
from pathlib import Path

possible_paths = [
    Path("course_v2/data/lesson13_orders.csv"),
    Path("data/lesson13_orders.csv"),
    Path("../../data/lesson13_orders.csv"),
    Path("lesson13_orders.csv"),
]

data_path = possible_paths[0]
for path in possible_paths:
    if path.exists():
        data_path = path
        break

if not data_path.exists():
    raise FileNotFoundError("找不到 lesson13_orders.csv，請確認已下載 course_v2/data 資料夾")

print("資料位置：", data_path)

import csv

# 1. 讀取資料

# 2. 計算總件數與總營業額

# 3. 找出城市與付款方式

# 4. 檢查缺值與重複編號

# 5. 寫出新的分析問題與需要欄位
